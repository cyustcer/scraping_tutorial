# %% [markdown]
# # Parse Information

# %%
import requests
URL = "https://www.imdb.com/chart/top"
r = requests.get(URL)
html = r.text
#print(r.text)

# %% [markdown]
# ## BeautifulSoup
# [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching and modifying the parse tree. It commonly saves programmers hours or days of work.

# %%
from bs4 import BeautifulSoup
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""
breakfast_soup = BeautifulSoup(html_doc, 'html.parser')
#print(breakfast_soup.prettify()) # Simplified tree structure of the html document
print("title of html: ", breakfast_soup.title) # The title, not the customized class "title", of the html
print("tag \'p\' of html: ", breakfast_soup.p) # The tag 'p' (paragraph) of the html
print("tag \'b\' of html: ", breakfast_soup.b) # The tag 'b' (boldtext) of the html
print("the class of tag \'p\' of html: ", breakfast_soup.p['class']) # The class of tag 'p' in the html
print("the first tag \'a\' of html: ", breakfast_soup.a) # The first tag 'a' (defines a hyperlink) of html
print("all \'a\' tags of html: ")  
a_s = breakfast_soup.find_all('a') # All tags 'a' of html
for a in a_s:
    print(a)
    print(a.get('href'))
print("context of id \'link3\': ", breakfast_soup.find(id='link3')) # Find the context by id "link3"
# Find the context by class 'title'
print("context of class \'title\': ", breakfast_soup.find('p', {"class": "title"}).get_text())
# Out:
# title of html:  <title>The Dormouse's story</title>
# tag 'p' of html:  <p class="title"><b>The Dormouse's story</b></p>
# tag 'b' of html:  <b>The Dormouse's story</b>
# the class of tag 'p' of html:  ['title']
# the first tag 'a' of html:  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# all 'a' tags of html:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# http://example.com/elsie
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# http://example.com/lacie
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# http://example.com/tillie
# context of id 'link3':  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# context of class 'title':  The Dormouse's story

# %%
soup = BeautifulSoup(html, features='lxml')
print("title of the page: ", soup.title.get_text())
print("head 1 of the body: ", soup.h1.get_text())
#print(dir(soup))
all_movies = soup.find_all('td', {"class": "titleColumn"}) # td: defines a cell in a table
print("Top 5 Movies in the history: ")
for movie in all_movies[:5]:
    print(movie.get_text())
    #print('\t', movie.a.get_text())
# Out:
# title of the page:  IMDb Top 250 - IMDb
# head 1 of the body:  Top Rated Movies
# Top 5 Movies in the history:
#
#       1.
#       The Shawshank Redemption
# (1994)
#
#
#       2.
#       The Godfather
# (1972)
#
#
#       3.
#       The Godfather: Part II
# (1974)
#
#
#       4.
#       The Dark Knight
# (2008)
#
#
#       5.
#       12 Angry Men
# (1957)

# %% [markdown]
# ### Save all posters of the top 250 movies in history
# - Open the url: https://www.imdb.com/chart/top
# - Find the one poster in the webpage, right click on it ans inspect
# - Understand the structure, make sure what tag, class or id it is under
# - Use the tag, class or id to locate all posters
# - Extract the information from them and save

# %%
import re # change names of images

all_posters = soup.find_all('td', {"class": "posterColumn"})

for poster in all_posters:
    url = poster.img['src']
    img_r = requests.get(url, stream=True)
    image_name = re.sub(r'\W', '_', poster.img['alt']) + '.' + url.split('.')[-1]
    with open('../img/IMDb/%s' % image_name, 'wb') as f:
        for chunk in img_r.iter_content(chunk_size=128):
            f.write(chunk)
    print('Saved %s' % image_name)

print("done!")
# Out:
# Saved The_Shawshank_Redemption.jpg
# Saved The_Godfather.jpg
# Saved The_Godfather__Part_II.jpg
# Saved The_Dark_Knight.jpg
# Saved 12_Angry_Men.jpg
# Saved Schindler_s_List.jpg
# Saved The_Lord_of_the_Rings__The_Return_of_the_King.jpg
# Saved Pulp_Fiction.jpg
# Saved The_Good__the_Bad_and_the_Ugly.jpg
# Saved Fight_Club.jpg
# Saved The_Lord_of_the_Rings__The_Fellowship_of_the_Ring.jpg
# Saved Forrest_Gump.jpg
# Saved Star_Wars__Episode_V___The_Empire_Strikes_Back.jpg
# Saved Inception.jpg
# Saved The_Lord_of_the_Rings__The_Two_Towers.jpg
# Saved One_Flew_Over_the_Cuckoo_s_Nest.jpg
# Saved Goodfellas.jpg
# Saved The_Matrix.jpg
# Saved Seven_Samurai.jpg
# Saved Se7en.jpg
# Saved City_of_God.jpg
# Saved Star_Wars__Episode_IV___A_New_Hope.jpg
# Saved The_Silence_of_the_Lambs.jpg
# Saved It_s_a_Wonderful_Life.jpg
# Saved Life_Is_Beautiful.jpg
# Saved Spider_Man__Into_the_Spider_Verse.jpg
# Saved The_Usual_Suspects.jpg
# Saved Spirited_Away.jpg
# Saved Saving_Private_Ryan.jpg
# Saved Léon__The_Professional.jpg
# Saved The_Green_Mile.jpg
# Saved Interstellar.jpg
# Saved Psycho.jpg
# Saved American_History_X.jpg
# Saved City_Lights.jpg
# Saved Once_Upon_a_Time_in_the_West.jpg
# Saved Casablanca.jpg
# Saved Modern_Times.jpg
# Saved The_Pianist.jpg
# Saved The_Intouchables.jpg
# Saved The_Departed.jpg
# Saved Back_to_the_Future.jpg
# Saved Terminator_2__Judgment_Day.jpg
# Saved Whiplash.jpg
# Saved Rear_Window.jpg
# Saved Raiders_of_the_Lost_Ark.jpg
# Saved The_Lion_King.jpg
# Saved Gladiator.jpg
# Saved The_Prestige.jpg
# Saved Apocalypse_Now.jpg
# Saved Memento.jpg
# Saved Alien.jpg
# Saved Cinema_Paradiso.jpg
# Saved The_Great_Dictator.jpg
# Saved Grave_of_the_Fireflies.jpg
# Saved Sunset_Blvd_.jpg
# Saved The_Lives_of_Others.jpg
# Saved Avengers__Infinity_War.jpg
# Saved Dr__Strangelove_or__How_I_Learned_to_Stop_Worrying_and_Love_the_Bomb.jpg
# Saved Paths_of_Glory.jpg
# Saved The_Shining.jpg
# Saved Django_Unchained.jpg
# Saved WALL_E.jpg
# Saved Princess_Mononoke.jpg
# Saved Witness_for_the_Prosecution.jpg
# Saved Oldeuboi.jpg
# Saved The_Dark_Knight_Rises.jpg
# Saved American_Beauty.jpg
# Saved Aliens.jpg
# Saved Once_Upon_a_Time_in_America.jpg
# Saved Coco.jpg
# Saved Das_Boot.jpg
# Saved Citizen_Kane.jpg
# Saved Braveheart.jpg
# Saved Vertigo.jpg
# Saved North_by_Northwest.jpg
# Saved Reservoir_Dogs.jpg
# Saved Star_Wars__Episode_VI___Return_of_the_Jedi.jpg
# Saved Your_Name_.jpg
# Saved M.jpg
# Saved Amadeus.jpg
# Saved Dangal.jpg
# Saved Requiem_for_a_Dream.jpg
# Saved Taare_Zameen_Par.jpg
# Saved Lawrence_of_Arabia.jpg
# Saved Eternal_Sunshine_of_the_Spotless_Mind.jpg
# Saved 3_Idiots.jpg
# Saved 2001__A_Space_Odyssey.jpg
# Saved A_Clockwork_Orange.jpg
# Saved Toy_Story.jpg
# Saved Amélie.jpg
# Saved Double_Indemnity.jpg
# Saved Singin__in_the_Rain.jpg
# Saved Taxi_Driver.jpg
# Saved Inglourious_Basterds.jpg
# Saved Full_Metal_Jacket.jpg
# Saved Bicycle_Thieves.jpg
# Saved To_Kill_a_Mockingbird.jpg
# Saved The_Kid.jpg
# Saved The_Sting.jpg
# Saved Good_Will_Hunting.jpg
# Saved Toy_Story_3.jpg
# Saved Jagten.jpg
# Saved Snatch.jpg
# Saved Scarface.jpg
# Saved Monty_Python_and_the_Holy_Grail.jpg
# Saved For_a_Few_Dollars_More.jpg
# Saved The_Apartment.jpg
# Saved Metropolis.jpg
# Saved L_A__Confidential.jpg
# Saved A_Separation.jpg
# Saved Indiana_Jones_and_the_Last_Crusade.jpg
# Saved Rashômon.jpg
# Saved Up.jpg
# Saved All_About_Eve.jpg
# Saved Batman_Begins.jpg
# Saved Yojimbo.jpg
# Saved Some_Like_It_Hot.jpg
# Saved Unforgiven.jpg
# Saved Downfall.jpg
# Saved Die_Hard.jpg
# Saved The_Treasure_of_the_Sierra_Madre.jpg
# Saved Heat.jpg
# Saved Andhadhun.jpg
# Saved Ikiru.jpg
# Saved Incendies.jpg
# Saved Raging_Bull.jpg
# Saved The_Great_Escape.jpg
# Saved Children_of_Heaven.jpg
# Saved Pan_s_Labyrinth.jpg
# Saved Babam_ve_Oglum.jpg
# Saved Chinatown.jpg
# Saved The_Third_Man.jpg
# Saved My_Neighbor_Totoro.jpg
# Saved Howl_s_Moving_Castle.jpg
# Saved Ran.jpg
# Saved Judgment_at_Nuremberg.jpg
# Saved The_Secret_in_Their_Eyes.jpg
# Saved The_Gold_Rush.jpg
# Saved Bohemian_Rhapsody.jpg
# Saved The_Bridge_on_the_River_Kwai.jpg
# Saved A_Beautiful_Mind.jpg
# Saved Lock__Stock_and_Two_Smoking_Barrels.jpg
# Saved Casino.jpg
# Saved Three_Billboards_Outside_Ebbing__Missouri.jpg
# Saved On_the_Waterfront.jpg
# Saved The_Seventh_Seal.jpg
# Saved Inside_Out.jpg
# Saved The_Elephant_Man.jpg
# Saved The_Wolf_of_Wall_Street.jpg
# Saved Room.jpg
# Saved V_for_Vendetta.jpg
# Saved Mr__Smith_Goes_to_Washington.jpg
# Saved Warrior.jpg
# Saved Blade_Runner.jpg
# Saved Dial_M_for_Murder.jpg
# Saved Wild_Strawberries.jpg
# Saved The_General.jpg
# Saved No_Country_for_Old_Men.jpg
# Saved Trainspotting.jpg
# Saved There_Will_Be_Blood.jpg
# Saved The_Sixth_Sense.jpg
# Saved Gone_with_the_Wind.jpg
# Saved The_Thing.jpg
# Saved Fargo.jpg
# Saved Gran_Torino.jpg
# Saved The_Deer_Hunter.jpg
# Saved Finding_Nemo.jpg
# Saved Come_and_See.jpg
# Saved Sherlock_Jr_.jpg
# Saved The_Big_Lebowski.jpg
# Saved Shutter_Island.jpg
# Saved Kill_Bill__Vol__1.jpg
# Saved Cool_Hand_Luke.jpg
# Saved Rebecca.jpg
# Saved Tokyo_Story.jpg
# Saved Mary_and_Max.jpg
# Saved Hacksaw_Ridge.jpg
# Saved Gone_Girl.jpg
# Saved How_to_Train_Your_Dragon.jpg
# Saved Sunrise.jpg
# Saved Relatos_salvajes.jpg
# Saved Jurassic_Park.jpg
# Saved Into_the_Wild.jpg
# Saved In_the_Name_of_the_Father.jpg
# Saved The_Truman_Show.jpg
# Saved The_Grand_Budapest_Hotel.jpg
# Saved Life_of_Brian.jpg
# Saved Stand_by_Me.jpg
# Saved It_Happened_One_Night.jpg
# Saved Platoon.jpg
# Saved The_Bandit.jpg
# Saved Stalker.jpg
# Saved Network.jpg
# Saved Memories_of_Murder.jpg
# Saved Persona.jpg
# Saved Ben_Hur.jpg
# Saved Hotel_Rwanda.jpg
# Saved 12_Years_a_Slave.jpg
# Saved Million_Dollar_Baby.jpg
# Saved Andrei_Rublev.jpg
# Saved The_Wages_of_Fear.jpg
# Saved Before_Sunrise.jpg
# Saved The_Passion_of_Joan_of_Arc.jpg
# Saved Rush.jpg
# Saved Mad_Max__Fury_Road.jpg
# Saved The_400_Blows.jpg
# Saved Prisoners.jpg
# Saved Hachi__A_Dog_s_Tale.jpg
# Saved Spotlight.jpg
# Saved Logan.jpg
# Saved Amores_Perros.jpg
# Saved Rang_De_Basanti.jpg
# Saved The_Princess_Bride.jpg
# Saved Catch_Me_If_You_Can.jpg
# Saved Nausicaä_of_the_Valley_of_the_Wind.jpg
# Saved Harry_Potter_and_the_Deathly_Hallows__Part_2.jpg
# Saved Butch_Cassidy_and_the_Sundance_Kid.jpg
# Saved Rocky.jpg
# Saved Barry_Lyndon.jpg
# Saved Monsters__Inc_.jpg
# Saved The_Grapes_of_Wrath.jpg
# Saved The_Maltese_Falcon.jpg
# Saved Dead_Poets_Society.jpg
# Saved The_Terminator.jpg
# Saved Donnie_Darko.jpg
# Saved Gandhi.jpg
# Saved Diabolique.jpg
# Saved La_Haine.jpg
# Saved Groundhog_Day.jpg
# Saved The_Wizard_of_Oz.jpg
# Saved In_the_Mood_for_Love.jpg
# Saved The_Nights_of_Cabiria.jpg
# Saved Jaws.jpg
# Saved The_Help.jpg
# Saved Tangerines.jpg
# Saved Ah_ga_ssi.jpg
# Saved Sanjuro.jpg
# Saved Before_Sunset.jpg
# Saved Drishyam.jpg
# Saved Paper_Moon.jpg
# Saved Paris__Texas.jpg
# Saved Castle_in_the_Sky.jpg
# Saved Gangs_of_Wasseypur.jpg
# Saved The_Best_Years_of_Our_Lives.jpg
# Saved Pirates_of_the_Caribbean__The_Curse_of_the_Black_Pearl.jpg
# Saved Fanny_and_Alexander.jpg
# Saved Guardians_of_the_Galaxy.jpg
# Saved Three_Colors__Red.jpg
# Saved 8½.jpg
# done!

# %% [markdown]
# ## lxml
# The [lxml](https://lxml.de/index.html) XML toolkit is a Pythonic binding for the C libraries __libxml2__ and __libxslt__. It is unique in that it combines the speed and XML feature completeness of the libraries with the simplicity of a native Python API, mostly compatible but superior to the well-known __ElementTree__ API.
#
# It is convinient to combine with the Xpath.

# %%
from lxml import etree
s = etree.HTML(html)
# The url of the poster of "The Shawshank Redemption"
print(s.xpath('//*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[1]/td[1]/a/img/@src'))
# tr (defines a row in a table)
# div (defines a section in a document)
# From the copied Xpath, we can tell
## tr[1] indicates the rank of the movie, i.e. tr[2] has the information of the 2nd movie, so on...
## td[1] contains the information of poster. So we can inspect more and guess td[2] has the information of the title,
## and td[3] has the information of the rating
## We can prove this by copying the xpath of the title and rating, then compare.
## Xpath of title: 
## //*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[1]/td[2]/a
## Xpath of the rating:
## //*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[1]/td[3]/strong
# The top 1 movie's name and rating
print('\n'+"Number 1:")
print(s.xpath('//*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[1]/td[2]/a/text()'))
print(s.xpath('//*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[1]/td[3]/strong/text()'))
print('\n'+"Number 2:")
print(s.xpath('//*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[2]/td[2]/a/text()'))
print(s.xpath('//*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[2]/td[3]/strong/text()'))
print('\n'+"Number 250")
print(s.xpath('//*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[last()]/td[2]/a/text()'))
print(s.xpath('//*[@id="main"]/div/span/div/div/div[3]/table/tbody/tr[last()]/td[3]/strong/text()'))
# Out:
# ['https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg']
#
# Number 1:
# ['The Shawshank Redemption']
# ['9.2']
#
# Number 2:
# ['The Godfather']
# ['9.2']
#
# Number 250
# ['8½']
# ['8.0']

# %% [markdown]
# ### Save the titles and ratings of the top 250 movies
# - Open the url: https://www.imdb.com/chart/top
# - Find the title and rating of one movie, and inspect
# - Study the Xpath of the title and rating
# - Write the Xpath
# - Extract the information

# %%
titles_list = s.xpath('//td[@class="titleColumn"]/a/text()')
ratings_list = s.xpath('//td[@class="ratingColumn imdbRating"]/strong/text()')
#print(titles_list[:10])
#print(ratings_list[:10])
imdb_list = list(zip(titles_list, ratings_list))
#print(imdb_list[:10])

# %%
import pandas as pd
df = pd.DataFrame(imdb_list, columns=["Title", "Rating"])
#print(list(df['Title']))
df.to_csv("./imdb.csv")
